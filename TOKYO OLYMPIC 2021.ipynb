# %%
import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

# %% [markdown]
# The Tokyo 2021 Winter Olympics brought together athletes from around the world to compete in a variety of exhilarating and awe-inspiring winter sports. Held in the vibrant and bustling city of Tokyo, Japan, this global sporting extravaganza showcased the pinnacle of athletic excellence, pushing the limits of human strength, skill, and determination.
#
#
# Alpine Skiing: In the stunning mountainous regions surrounding Tokyo, athletes showcased their prowess in alpine skiing. Speeding down the slopes, they maneuvered through challenging courses, defying gravity and showcasing remarkable control and precision as they navigated through gates and tackled the sharp turns.
#
#
# Snowboarding: Tokyo 2021 Winter Olympics also witnessed the heart-pounding excitement of snowboarding events. Athletes showcased their artistry and daring as they executed breathtaking jumps, spins, and flips in the halfpipe and slopestyle competitions. Their skillful maneuvers and gravity-defying tricks left spectators in awe, providing thrilling moments of high-flying action.
#
#
# Ice Hockey: The Winter Olympics wouldn't be complete without the fast-paced and fiercely competitive ice hockey tournaments. Teams from various nations clashed on the ice, displaying a blend of skill, speed, and physicality. The crowd cheered as players deftly maneuvered the puck, executed precision passes, and launched powerful shots towards the goal, making for intense and unforgettable moments.
#
#
# Figure Skating: Tokyo 2021 Winter Olympics brought the elegance and grace of figure skating to the forefront. Dazzling performances took place on the glistening ice, as skaters flawlessly executed intricate jumps, spins, and choreographed routines. Their movements, synchronized with the music, created an ethereal spectacle, captivating audiences with their technical prowess and artistry.
#
#
# Biathlon: Combining the disciplines of cross-country skiing and rifle shooting, the biathlon tests athletes' endurance, precision, and focus. Competitors raced through snowy tracks, their hearts pounding as they approached the shooting range. Steadying their breath, they aimed at the targets with incredible accuracy before resuming their demanding ski trek, vying for both speed and marksmanship.
#
#
# Speed Skating: The Tokyo 2021 Winter Olympics also featured the thrilling sport of speed skating, where athletes pushed their limits on the icy oval. With incredible speed and power, skaters raced against the clock, striving to break records and claim victory. The intense bursts of energy, gliding strides, and hairpin turns created a gripping spectacle for spectators.
#
#
# Curling: The Winter Olympics embraced the strategic and skillful game of curling, where teams competed by sliding stones on a sheet of ice, aiming to position them precisely in target areas. Sweeping the ice in front of the stone, players strategically guided their way to victory, displaying precision, teamwork, and tactics.
#
#
# These were just a few of the remarkable events that took place during the Tokyo 2021 Winter Olympics. The games brought together athletes from different nations and backgrounds, fostering a spirit of unity and friendly competition. The world watched in awe as these exceptional individuals showcased their talent, dedication, and unwavering commitment to their respective sports, leaving a lasting legacy of sporting excellence and unforgettable moments in the history of the Winter Olympics.

# %% [markdown]
# # Athletes details in Excel Format

# %%
olympic = pd.read_excel("Athletes.xlsx")

olympic
# Out:
#                      Name                       NOC     Discipline
# 0             AALTO Antti                   Finland    Ski Jumping
# 1           AALTONEN Miro                   Finland     Ice Hockey
# 2       ABDELKADER Justin  United States of America     Ice Hockey
# 3              ABDI Fayik              Saudi Arabia  Alpine Skiing
# 4     ABDUL-SABOOR Hakeem  United States of America      Bobsleigh
# ...                   ...                       ...            ...
# 2887         ZUREK Damian                    Poland  Speed Skating
# 2888        ZUYEVA Maryna                   Belarus  Speed Skating
# 2889          ZUZIN Peter                  Slovakia     Ice Hockey
# 2890       ZVEJNIEKS Miks                    Latvia  Alpine Skiing
# 2891           ZYLA Piotr                    Poland    Ski Jumping
#
# [2892 rows x 3 columns]

# %% [markdown]
# # Sample Data set

# %%
olympic.head()
# Out:
#                   Name                       NOC     Discipline
# 0          AALTO Antti                   Finland    Ski Jumping
# 1        AALTONEN Miro                   Finland     Ice Hockey
# 2    ABDELKADER Justin  United States of America     Ice Hockey
# 3           ABDI Fayik              Saudi Arabia  Alpine Skiing
# 4  ABDUL-SABOOR Hakeem  United States of America      Bobsleigh

# %%
olympic.tail()
# Out:
#                 Name       NOC     Discipline
# 2887    ZUREK Damian    Poland  Speed Skating
# 2888   ZUYEVA Maryna   Belarus  Speed Skating
# 2889     ZUZIN Peter  Slovakia     Ice Hockey
# 2890  ZVEJNIEKS Miks    Latvia  Alpine Skiing
# 2891      ZYLA Piotr    Poland    Ski Jumping

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Total number of Rows and Columns in data set

# %%
olympic.shape
# Out:
# (2892, 3)

# %% [markdown]
# # Find total no of data types based on no of features

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2892 entries, 0 to 2891
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        2892 non-null   object
#  1   NOC         2892 non-null   object
#  2   Discipline  2892 non-null   object
# dtypes: object(3)
# memory usage: 67.9+ KB

# %% [markdown]
# # To Find the aggregation details using describe function

# %%
olympic.describe()
# Out:
#                Name                       NOC  Discipline
# count          2892                      2892        2892
# unique         2889                        91          15
# top     ZHAO Jiawen  United States of America  Ice Hockey
# freq              2                       225         548

# %% [markdown]
# # Checking the total missing values in the total no of columns

# %%
olympic.isnull().sum()
# Out:
# Name          0
# NOC           0
# Discipline    0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# 1. Which countries do most athletes come from?

# %%
olympic.head()
# Out:
#                   Name                       NOC     Discipline
# 0          AALTO Antti                   Finland    Ski Jumping
# 1        AALTONEN Miro                   Finland     Ice Hockey
# 2    ABDELKADER Justin  United States of America     Ice Hockey
# 3           ABDI Fayik              Saudi Arabia  Alpine Skiing
# 4  ABDUL-SABOOR Hakeem  United States of America      Bobsleigh

# %% [markdown]
# # Find the unique values in the 'Name' column

# %%
unique_values = olympic['Name'].unique()

unique_values
# Out:
# array(['AALTO Antti', 'AALTONEN Miro', 'ABDELKADER Justin', ...,
#        'ZUZIN Peter', 'ZVEJNIEKS Miks', 'ZYLA Piotr'], dtype=object)

# %% [markdown]
# # Find the unique values in the 'NOC' column

# %%
unique_values = olympic['NOC'].unique()

unique_values
# Out:
# array(['Finland', 'United States of America', 'Saudi Arabia', 'Eritrea',
#        'Germany', 'Latvia', 'Ukraine', 'Netherlands',
#        "People's Republic of China", 'France', 'Sweden', 'Switzerland',
#        'Belgium', 'Islamic Republic of Iran', 'Kazakhstan', 'Estonia',
#        'ROC', 'Turkey', 'Monaco', 'Jamaica', 'Bosnia and Herzegovina',
#        'Belarus', 'Canada', 'Italy', 'Denmark', 'Norway', 'Japan',
#        'Greece', 'Bulgaria', 'Australia', 'Morocco', 'Chile', 'Ireland',
#        'Mongolia', 'Lebanon', 'Croatia', 'Great Britain',
#        'Republic of Korea', 'Austria', 'Slovakia', 'Lithuania',
#        'New Zealand', 'Spain', 'Czech Republic', 'Argentina', 'Georgia',
#        'Poland', 'Brazil', 'Slovenia', 'Portugal', 'Bolivia',
#        'Trinidad and Tobago', 'Israel', 'Romania', 'Mexico', 'Thailand',
#        'Hungary', 'Hong Kong, China', 'Madagascar', 'American Samoa',
#        'North Macedonia', 'Puerto Rico', 'Republic of Moldova', 'Iceland',
# ...

# %% [markdown]
# # Find the unique values in the 'Discipline' column

# %%
unique_values = olympic['Discipline'].unique()

unique_values
# Out:
# array(['Ski Jumping', 'Ice Hockey', 'Alpine Skiing', 'Bobsleigh',
#        'Freestyle Skiing', 'Speed Skating', 'Short Track Speed Skating',
#        'Cross-Country Skiing', 'Biathlon', 'Figure Skating',
#        'Nordic Combined', 'Snowboard', 'Luge', 'Curling', 'Skeleton'],
#       dtype=object)

# %% [markdown]
# # Total number of value counts in the 'NOC' column

# %%
olympic['NOC'].value_counts()
# Out:
# United States of America      225
# ROC                           217
# Canada                        217
# People's Republic of China    176
# Switzerland                   169
#                              ...
# American Samoa                  1
# Saudi Arabia                    1
# Eritrea                         1
# Morocco                         1
# Albania                         1
# Name: NOC, Length: 91, dtype: int64

# %% [markdown]
# We will use value_counts to get a sorted order of values so we can use a fixed number of values to demonstrate which countries most players come from. Using all the countries would make the chart too clustered.

# %%
# %matplotlib inline



countries_group = olympic.groupby('NOC')
countries = [NOC for NOC, olympic in countries_group]

y = olympic.NOC.value_counts().values[0:31]
x = olympic.NOC.value_counts().index[0:31]

plt.figure(figsize=(20,5))
plt.bar(x,y)
plt.xlabel("Countries")
plt.ylabel("Number of athletes")
plt.xticks(rotation='vertical',size=10)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# Observation:
#
# United States of America country there are highest number of atheletes ie. 225 who have participated in the Olympic 2021

# %% [markdown]
# # Total number of value counts in the 'Discipline' column

# %%
olympic['Discipline'].value_counts()
# Out:
# Ice Hockey                   548
# Alpine Skiing                310
# Cross-Country Skiing         298
# Freestyle Skiing             272
# Snowboard                    233
# Biathlon                     212
# Speed Skating                165
# Bobsleigh                    163
# Figure Skating               148
# Curling                      114
# Short Track Speed Skating    112
# Ski Jumping                  106
# Luge                         106
# Nordic Combined               55
# Skeleton                      50
# Name: Discipline, dtype: int64

# %% [markdown]
# 2. Which discipline is most popular and which country has the highest participants in it?

# %%
countries_group = olympic.groupby('Discipline')
countries = [Discipline for Discipline, olympic in countries_group]

y = olympic.Discipline.value_counts().values[0:31]
x = olympic.Discipline.value_counts().index[0:31]

plt.figure(figsize=(20,5))
plt.bar(x,y)

for index, value in enumerate(y):
    
    plt.text(index, value, str(value),color='red',size=12,fontweight='bold')
    
plt.xlabel("Discipline")
plt.ylabel("Number of athletes")
plt.xticks(rotation='vertical',size=10)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# Observation:
#
# In the Ice Hockey Discipline and United States of America country have highest number of atheletes who have participated in the Olympic 2021

# %% [markdown]
# # Total number of value counts in the 'Name' and 'NOC' columns

# %%
olympic[['Name','NOC']].value_counts()
# Out:
# Name                        NOC
# LEDECKA Ester               Czech Republic                2
# BENDIKA Baiba               Latvia                        2
# ZHAO Jiawen                 People's Republic of China    2
# PAULOVA Zuzana              Czech Republic                1
# PATKOVA Kristyna            Czech Republic                1
#                                                          ..
# HOFFOS Courtney             Canada                        1
# HOFMANN Gregory             Switzerland                   1
# HOFMEISTER Ramona Theresia  Germany                       1
# HOGAS Mihaela               Romania                       1
# von APPEN Henrik            Chile                         1
# Length: 2889, dtype: int64

# %% [markdown]
# # Total number of value counts in the 'Name' and 'Discipline' columns

# %%
olympic[['Name','Discipline']].value_counts()
# Out:
# Name                        Discipline
# AALTO Antti                 Ski Jumping         1
# PASCHKE Pius                Ski Jumping         1
# PASTERNACK Nadja            Bobsleigh           1
# PATKOVA Kristyna            Ice Hockey          1
# PATRICIAN Chris             Bobsleigh           1
#                                                ..
# HOFFMANN Anna               Ski Jumping         1
# HOFFOS Courtney             Freestyle Skiing    1
# HOFMANN Gregory             Ice Hockey          1
# HOFMEISTER Ramona Theresia  Snowboard           1
# von APPEN Henrik            Alpine Skiing       1
# Length: 2892, dtype: int64

# %%
olympic1 = pd.read_excel("Teams.xlsx")

olympic1
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                            Name                         NOC  \
# 0                     Australia                   Australia
# 1                        Canada                      Canada
# 2                        Canada                      Canada
# 3                        Canada                      Canada
# 4    People's Republic of China  People's Republic of China
# ..                          ...                         ...
# 158                         ROC                         ROC
# 159                         ROC                         ROC
# 160                         ROC                         ROC
# 161    United States of America    United States of America
# 162    United States of America    United States of America
#
# ...

# %%
olympic1.head()
# Out:
#                          Name                         NOC Discipline  \
# 0                   Australia                   Australia    Curling
# 1                      Canada                      Canada    Curling
# 2                      Canada                      Canada    Curling
# 3                      Canada                      Canada    Curling
# 4  People's Republic of China  People's Republic of China    Curling
#
#            Event
# 0  Mixed Doubles
# 1            Men
# 2  Mixed Doubles
# 3          Women
# 4            Men

# %%
olympic1["NOC"].value_counts()
# Out:
# ROC                           20
# Canada                        19
# United States of America      18
# People's Republic of China    15
# Italy                         12
# Japan                          9
# Czech Republic                 8
# Germany                        6
# Switzerland                    5
# Georgia                        5
# Sweden                         5
# Denmark                        4
# Great Britain                  4
# Republic of Korea              4
# Poland                         3
# Hungary                        3
# Netherlands                    3
# Finland                        3
# Ukraine                        3
# France                         2
# Norway                         2
# Spain                          2
# Kazakhstan                     1
# Slovakia                       1
# Latvia                         1
# Australia                      1
# Lithuania                      1
# Israel                         1
# ...

# %% [markdown]
# In the most popular discipline based on NOC has most number of participants ROC(20), Canada (19), United States of America (18), People's Republic of China (15), Italy (12).

# %% [markdown]
# # Total value counts of 'Event' and 'Discipline' columns

# %%
event_counts = olympic1.groupby("Event")["Discipline"].value_counts()
print(event_counts)
# Out:
# Event                Discipline
# Ice Dance            Figure Skating               23
# Men                  Ice Hockey                   12
#                      Curling                      10
# Men's 5000m Relay    Short Track Speed Skating     8
# Mixed Doubles        Curling                      10
# Mixed Team Relay     Short Track Speed Skating    12
# Pair Skating         Figure Skating               19
# Team Event           Figure Skating               41
# Women                Curling                      10
#                      Ice Hockey                   10
# Women's 3000m Relay  Short Track Speed Skating     8
# Name: Discipline, dtype: int64

# %%
olympic2 = pd.read_excel("Entries_By_Discipline.xlsx")

olympic2
# Out:
#                    Discipline  Female  Male  Total
# 0               Alpine Skiing     153   157    310
# 1                    Biathlon     105   107    212
# 2                   Bobsleigh      46   117    163
# 3        Cross-Country Skiing     149   149    298
# 4                     Curling      59    55    114
# 5              Figure Skating      74    74    148
# 6            Freestyle Skiing     130   142    272
# 7                  Ice Hockey     234   314    548
# 8                        Luge      35    71    106
# 9             Nordic Combined       0    55     55
# 10  Short Track Speed Skating      54    58    112
# 11                   Skeleton      25    25     50
# 12                Ski Jumping      40    66    106
# 13                  Snowboard     114   119    233
# 14              Speed Skating      78    87    165
# 15                      Total    1296  1596   2892

# %% [markdown]
# # Total no of male counts based on Discipline column

# %%
male_counts = olympic2.groupby("Discipline")["Male"].sum()
print(male_counts)
# Out:
# Discipline
# Alpine Skiing                 157
# Biathlon                      107
# Bobsleigh                     117
# Cross-Country Skiing          149
# Curling                        55
# Figure Skating                 74
# Freestyle Skiing              142
# Ice Hockey                    314
# Luge                           71
# Nordic Combined                55
# Short Track Speed Skating      58
# Skeleton                       25
# Ski Jumping                    66
# Snowboard                     119
# Speed Skating                  87
# Total                        1596
# Name: Male, dtype: int64

# %% [markdown]
# # Total no of Female counts based on Discipline column

# %%
Female_counts = olympic2.groupby("Discipline")["Female"].sum()
print(Female_counts)
# Out:
# Discipline
# Alpine Skiing                 153
# Biathlon                      105
# Bobsleigh                      46
# Cross-Country Skiing          149
# Curling                        59
# Figure Skating                 74
# Freestyle Skiing              130
# Ice Hockey                    234
# Luge                           35
# Nordic Combined                 0
# Short Track Speed Skating      54
# Skeleton                       25
# Ski Jumping                    40
# Snowboard                     114
# Speed Skating                  78
# Total                        1296
# Name: Female, dtype: int64

# %%
Discipline_count = olympic2.groupby('Discipline')
x = [Discipline for Discipline, olympic2 in Discipline_count]

female = olympic2.Female
male =   olympic2.Male
plt.figure(figsize=(20,8))
X_axis = np.arange(len(x))
plt.bar(X_axis - 0.2, female, 0.4, label = 'Female')
plt.bar(X_axis + 0.2, male, 0.4, label = 'Male')

plt.xlabel("Discipline",size=10)
plt.ylabel("Number of Participants")
plt.xticks(X_axis,x,rotation='vertical')
plt.legend()
plt.show()

# %%
olympic3 = pd.read_excel("Technical_Coaches.xlsx")

olympic3
# Out:
#                          Name      Discipline
# 0                 ABELE Agita  Figure Skating
# 1                AHN Na Young  Figure Skating
# 2              ANDREEVA Julia  Figure Skating
# 3            BAKKER Ernestien  Figure Skating
# 4              BENSON Cynthia  Figure Skating
# 5            BIANCHETTI Fabio  Figure Skating
# 6            BINDER Elisabeth  Figure Skating
# 7            BRAMBATI Claudia  Figure Skating
# 8            BUTTARELLI Marco  Figure Skating
# 9              CESARO Michela  Figure Skating
# 10               DERBY Andrea  Figure Skating
# 11                   FANG Dan  Figure Skating
# 12               FOMINA Elena  Figure Skating
# 13               GRAHAM Peggy  Figure Skating
# 14          HOUGHTON Patricia  Figure Skating
# 15              HUNTER Janice  Figure Skating
# 16              JUST Bernhard  Figure Skating
# 17                KANTOR Anna  Figure Skating
# 18           KLIUSHNIKOV Yury  Figure Skating
# ...

# %% [markdown]
# # Total value counts from Discipline columns based on 'Technical_Coaches' data set

# %%
discipline_counts = olympic3['Discipline'].value_counts()

discipline_counts
# Out:
# Figure Skating    56
# Name: Discipline, dtype: int64

# %%
discipline_counts = olympic3['Discipline'].value_counts().reset_index()

# Rename the columns for clarity
discipline_counts.columns = ['Discipline', 'Count']

# Create a grouped bar plot
sns.barplot(x='Discipline', y='Count', data=discipline_counts)

# Customize the plot
plt.title('Count of technical_coaches by Discipline')
plt.xlabel('Discipline')
plt.ylabel('Count')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
olympic4 = pd.read_excel("Coaches.xlsx")

olympic4
# Out:
#                    Name                         NOC  Discipline          Event
# 0           BARES Jakub              Czech Republic     Curling  Mixed Doubles
# 1         BEIGHTON Sean    United States of America     Curling            Men
# 2         BEIGHTON Sean    United States of America     Curling  Mixed Doubles
# 3        BELANOV Sergei                         ROC     Curling          Women
# 4      BOBARIKO Yevgeni                         ROC  Ice Hockey          Women
# ..                  ...                         ...         ...            ...
# 73     WAIBEL Karlheinz                     Germany     Curling            NaN
# 74      WIGGERUD Anders                      Sweden     Curling            NaN
# 75  WOOLLEY Christopher                 Switzerland     Curling            NaN
# 76        ZANATTA Ivano  People's Republic of China  Ice Hockey            Men
# 77       ZHAMNOV Alexei                         ROC  Ice Hockey            Men
#
# [78 rows x 4 columns]

# %%
olympic4.isnull().sum()
# Out:
# Name           0
# NOC            0
# Discipline     0
# Event         24
# dtype: int64

# %% [markdown]
# Observation:
#
# There are total 24 missing values in the Event column

# %% [markdown]
# Removed the Event column which consist missing values

# %% [markdown]
# 3. Which country produces highest number of coaches?

# %%
olympic4 = olympic4.dropna(axis=1)

olympic4
# Out:
#                    Name                         NOC  Discipline
# 0           BARES Jakub              Czech Republic     Curling
# 1         BEIGHTON Sean    United States of America     Curling
# 2         BEIGHTON Sean    United States of America     Curling
# 3        BELANOV Sergei                         ROC     Curling
# 4      BOBARIKO Yevgeni                         ROC  Ice Hockey
# ..                  ...                         ...         ...
# 73     WAIBEL Karlheinz                     Germany     Curling
# 74      WIGGERUD Anders                      Sweden     Curling
# 75  WOOLLEY Christopher                 Switzerland     Curling
# 76        ZANATTA Ivano  People's Republic of China  Ice Hockey
# 77       ZHAMNOV Alexei                         ROC  Ice Hockey
#
# [78 rows x 3 columns]

# %%
olympic4.NOC.value_counts()
# Out:
# Switzerland                   11
# Denmark                        9
# Canada                         8
# Sweden                         8
# People's Republic of China     7
# United States of America       5
# ROC                            4
# Great Britain                  4
# Norway                         4
# Czech Republic                 3
# Italy                          3
# Japan                          3
# Finland                        3
# Germany                        2
# Slovakia                       1
# Republic of Korea              1
# Australia                      1
# Latvia                         1
# Name: NOC, dtype: int64

# %%
discipline_counts = olympic4['Discipline'].value_counts()

discipline_counts
# Out:
# Curling       51
# Ice Hockey    27
# Name: Discipline, dtype: int64

# %%
discipline_counts = olympic4['Discipline'].value_counts().reset_index()

# Rename the columns for clarity
discipline_counts.columns = ['Discipline', 'Count']

# Create a grouped bar plot
sns.barplot(x='Discipline', y='Count', data=discipline_counts)

# Customize the plot
plt.title('Count of coaches by Discipline')
plt.xlabel('Discipline')
plt.ylabel('Count')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# 4.Which country recieved most gold medals? Which recieved most silver and most bronze? Which received least for each?

# %%
olympic5 = pd.read_excel("Medals_2022.xlsx")

olympic5
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     Rank                         NOC  Gold  Silver  Bronze  Total  \
# 0      1                      Norway    16       8      13     37
# 1      2                     Germany    12      10       5     27
# 2      3  People's Republic of China     9       4       2     15
# 3      4    United States of America     8      10       7     25
# 4      5                      Sweden     8       5       5     18
# 5      6                 Netherlands     8       5       4     17
# 6      7                     Austria     7       7       4     18
# 7      8                 Switzerland     7       2       5     14
# 8      9                         ROC     6      12      14     32
# 9     10                      France     5       7       2     14
# ...

# %% [markdown]
# Observation:
#
# Spain, ukraine, Estonia, Latvia, Poland countries have least number of medals and they are ranked in 25.
#
# Spain: Gold medal : 0 , Silver Medal : 1, Bronze medal : 0
#
# Ukraine: Gold Medal: 0, Silver Medal :  1, Bronze medal: 0
#
# Estonia: Gold Medal: 0, Silver medal: 0 , Bronze medal: 1
#
# Latvia:	Gold Medal: 0, Silver medal: 0 , Bronze medal: 1
#
# Poland: Gold Medal: 0, Silver medal: 0 , Bronze medal: 1

# %%
medals = ['Gold', 'Silver', 'Bronze']
NOC_medal_counts = olympic5.groupby('NOC')[medals].sum()

NOC_medal_counts
# Out:
#                             Gold  Silver  Bronze
# NOC
# Australia                      1       2       1
# Austria                        7       7       4
# Belarus                        0       2       0
# Belgium                        1       0       1
# Canada                         4       8      14
# Czech Republic                 1       0       1
# Estonia                        0       0       1
# Finland                        2       2       4
# France                         5       7       2
# Germany                       12      10       5
# Great Britain                  1       1       0
# Hungary                        1       0       2
# Italy                          2       7       8
# Japan                          3       6       9
# Latvia                         0       0       1
# Netherlands                    8       5       4
# New Zealand                    2       1       0
# Norway                        16       8      13
# ...

# %%
sorted_olympic5 = olympic5.sort_values('Rank by Total', ascending=True)

sorted_olympic5
# Out:
#     Rank                         NOC  Gold  Silver  Bronze  Total  \
# 0      1                      Norway    16       8      13     37
# 8      9                         ROC     6      12      14     32
# 1      2                     Germany    12      10       5     27
# 10    11                      Canada     4       8      14     26
# 3      4    United States of America     8      10       7     25
# 4      5                      Sweden     8       5       5     18
# 6      7                     Austria     7       7       4     18
# 11    12                       Japan     3       6       9     18
# 5      6                 Netherlands     8       5       4     17
# 12    13                       Italy     2       7       8     17
# 2      3  People's Republic of China     9       4       2     15
# 7      8                 Switzerland     7       2       5     14
# 9     10                      France     5       7       2     14
# ...

# %%
Rank_NOC_medal = olympic5.groupby('NOC')['Rank by Total'].value_counts().reset_index(name='Count')


Rank_NOC_medal
# Out:
#                            NOC  Rank by Total  Count
# 0                    Australia             17      1
# 1                      Austria              6      1
# 2                      Belarus             20      1
# 3                      Belgium             20      1
# 4                       Canada              4      1
# 5               Czech Republic             20      1
# 6                      Estonia             25      1
# 7                      Finland             15      1
# 8                       France             12      1
# 9                      Germany              3      1
# 10               Great Britain             20      1
# 11                     Hungary             18      1
# 12                       Italy              9      1
# 13                       Japan              6      1
# 14                      Latvia             25      1
# 15                 Netherlands              9      1
# 16                 New Zealand             18      1
# ...

# %%
x = []
for NOC in olympic5.NOC:
    x.append(NOC)
y = olympic5.Gold
plt.figure(figsize=(30,8))
plt.bar(x,y)
for index, value in enumerate(y):
    plt.text(index, value, str(value),color='red',size=15,fontweight='bold')
plt.xlabel("Country",size=10)
plt.ylabel("Gold Medals")
plt.xticks(x,rotation='vertical',size=15)
plt.title("Gold Medals across Nations")
plt.show()

# %% [markdown]
# Observation:
#
# Norway country have highest number of Gold medals ie. 10 across all nations

# %%
x = []
for NOC in olympic5.NOC:
    x.append(NOC)
y = olympic5.Silver
plt.figure(figsize=(30,8))
plt.bar(x,y)
for index, value in enumerate(y):
    plt.text(index, value, str(value),color='red',size=15,fontweight='bold')
plt.xlabel("Country",size=10)
plt.ylabel("Silver Medals")
plt.xticks(x,rotation='vertical',size=15)
plt.title("Silver Medals across Nations")
plt.show()

# %% [markdown]
# Observation:
#
# ROC country have highest number of Silver medals ie. 12 across all nations

# %%
x = []
for NOC in olympic5.NOC:
    x.append(NOC)
y = olympic5.Bronze
plt.figure(figsize=(30,8))
plt.bar(x,y)
for index, value in enumerate(y):
    plt.text(index, value, str(value),color='red',size=15,fontweight='bold')
plt.xlabel("Country",size=10)
plt.ylabel("Bronze Medals")
plt.xticks(x,rotation='vertical',size=15)
plt.title("Bronze Medals across Nations")
plt.show()

# %% [markdown]
# Observation:
#
# ROC and Canada countries have highest number of Bronze medals ie. 14 across all nations
